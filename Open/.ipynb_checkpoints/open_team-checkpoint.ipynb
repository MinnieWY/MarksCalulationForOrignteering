# %%
import pandas as pd
from datetime import timedelta
from datetime import datetime

# Declare variable here
startTime = datetime(2023,2,12,13,30,47)
gen_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
correct = "correct"
question_key = "問題Question"
question = "question"

# %%
#P001 聖德肋撒堂
cp01 = pd.read_csv('./open_record/01.csv')
cp01.rename(columns={question_key:question},inplace=True)
cp01['CP01']='' 
cp01.loc[cp01.question == correct, 'CP01'] = 50
cp01.loc[cp01.question != correct, 'CP01'] = 0
cp01.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp01 = cp01.drop_duplicates(subset=['Team Name (Hide)'])

#P002 聖安德烈堂
cp02 = pd.read_csv('./open_record/02.csv')
cp02.rename(columns={question_key:question},inplace=True)
cp02['CP02']='' 
cp02.loc[cp02.question == correct, 'CP02'] = 50
cp02.loc[cp02.question != correct, 'CP02'] = 0
cp02.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp02 = cp02.drop_duplicates(subset=['Team Name (Hide)'])

#P003 香港女童軍新總部大樓地盤
cp03 = pd.read_csv('./open_record/03.csv')
cp03.rename(columns={question_key:question},inplace=True)
cp03['CP03']='' 
cp03.loc[cp03.question == correct, 'CP03'] = 50
cp03.loc[cp03.question != correct, 'CP03'] = 0
cp03.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp03 = cp03.drop_duplicates(subset=['Team Name (Hide)'])

#P004 西九文化區 (1)
cp04 = pd.read_csv('./open_record/04.csv')
cp04.rename(columns={question_key:question},inplace=True)
cp04['CP04']='' 
cp04.loc[cp04.question == correct, 'CP04'] = 50
cp04.loc[cp04.question != correct, 'CP04'] = 0
cp04.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp04 = cp04.drop_duplicates(subset=['Team Name (Hide)'])

#P005 油麻地果欄
cp05 = pd.read_csv('./open_record/05.csv')
cp05.rename(columns={question_key:question},inplace=True)
cp05['CP05']='' 
cp05.loc[cp05.question == correct, 'CP05'] = 30
cp05.loc[cp05.question != correct, 'CP05'] = 0
cp05.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp05 = cp05.drop_duplicates(subset=['Team Name (Hide)'])

#P006 海富苑遊樂場
cp06 = pd.read_csv('./open_record/06.csv')
cp06.rename(columns={question_key:question},inplace=True)
cp06['CP06']='' 
cp06.loc[cp06.question == correct, 'CP06'] = 30
cp06.loc[cp06.question != correct, 'CP06'] = 0
cp06.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp06 = cp06.drop_duplicates(subset=['Team Name (Hide)'])

#P007 西九文化區 (2)
cp07 = pd.read_csv('./open_record/07.csv')
cp07.rename(columns={question_key:question},inplace=True)
cp07['CP07']='' 
cp07.loc[cp07.question == correct, 'CP07'] = 10
cp07.loc[cp07.question != correct, 'CP07'] = 0
cp07.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp07 = cp07.drop_duplicates(subset=['Team Name (Hide)'])

#P008 香港歷史博物館
cp08 = pd.read_csv('./open_record/08.csv')
cp08.rename(columns={question_key:question},inplace=True)
cp08['CP08']='' 
cp08.loc[cp08.question == correct, 'CP08'] = 10
cp08.loc[cp08.question != correct, 'CP08'] = 0
cp08.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp08 = cp08.drop_duplicates(subset=['Team Name (Hide)'])

#P009 百週年紀念公園
cp09 = pd.read_csv('./open_record/09.csv')
cp09.rename(columns={question_key:question},inplace=True)
cp09['CP09']='' 
cp09.loc[cp09.question == correct, 'CP09'] = 10
cp09.loc[cp09.question != correct, 'CP09'] = 0
cp09.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp09 = cp09.drop_duplicates(subset=['Team Name (Hide)'])

#P010 玉器市場
cp10 = pd.read_csv('./open_record/10.csv')
cp10.rename(columns={question_key:question},inplace=True)
cp10['CP10']='' 
cp10.loc[cp10.question == correct, 'CP10'] = 10
cp10.loc[cp10.question != correct, 'CP10'] = 0
cp10.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp10 = cp10.drop_duplicates(subset=['Team Name (Hide)'])

#P011 花園街
cp11 = pd.read_csv('./open_record/11.csv')
cp11.rename(columns={question_key:question},inplace=True)
cp11['CP11']='' 
cp11.loc[cp11.question == correct, 'CP11'] = 10
cp11.loc[cp11.question != correct, 'CP11'] = 0
cp11.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp11 = cp11.drop_duplicates(subset=['Team Name (Hide)'])

#P012 山東街水月宮
cp12 = pd.read_csv('./open_record/12.csv')
cp12.rename(columns={question_key:question},inplace=True)
cp12['CP12']='' 
cp12.loc[cp12.question == correct, 'CP12'] = 10
cp12.loc[cp12.question != correct, 'CP12'] = 0
cp12.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp12 = cp12.drop_duplicates(subset=['Team Name (Hide)'])

#P013 廟街
cp13 = pd.read_csv('./open_record/13.csv')
cp13.rename(columns={question_key:question},inplace=True)
cp13['CP13']='' 
cp13.loc[cp13.question == correct, 'CP13'] = 10
cp13.loc[cp13.question != correct, 'CP13'] = 0
cp13.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp13 = cp13.drop_duplicates(subset=['Team Name (Hide)'])

#P0014 油尖旺多元文化中心
cp14 = pd.read_csv('./open_record/14.csv')
cp14.rename(columns={question_key:question},inplace=True)
cp14['CP14']='' 
cp14.loc[cp14.question == correct, 'CP14'] = 10
cp14.loc[cp14.question != correct, 'CP14'] = 0
cp14.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp14 = cp14.drop_duplicates(subset=['Team Name (Hide)'])

#P015 雀鳥公園
cp15 = pd.read_csv('./open_record/15.csv')
cp15.rename(columns={question_key:question},inplace=True)
cp15['cp15']='' 
cp15.loc[cp15.question == correct, 'CP15'] = 10
cp15.loc[cp15.question != correct, 'CP15'] = 0
cp15.drop(labels=["ObjectID","CreationDate","GlobalID","Editor", "Creator", "x","y", question, "EditDate"], axis=1, inplace=True)
cp15 = cp15.drop_duplicates(subset=['Team Name (Hide)'])

#P0016 香港女童軍總會
cp16 = pd.read_csv('./open_record/16.csv')
cp16.rename(columns={question_key:question},inplace=True)
cp16.rename(columns={"EditDate":"FinishTime"},inplace=True)
cp16.drop(labels=["ObjectID","CreationDate","GlobalID", "Editor","Creator", "x","y",question], axis=1, inplace=True)
cp16 = cp16.drop_duplicates(subset=['Team Name (Hide)'])

# %%
df_list = [cp01,cp02,cp03,cp04,cp05,cp06,cp07,cp08,cp09,cp10,cp11,cp12,cp13,cp14,cp15,cp16]
master = df_list[0]
for df in df_list[1:]:
    master = pd.merge(master, df, on='Team Name (Hide)', how="outer")
master = master.drop_duplicates(subset=['Team Name (Hide)'])
master['Total Time']=''
master['IsComplete']=False
master['Total Score']=0

pd.options.display.float_format = '{:,.0f}'.format

master.rename(columns={"Team Name (Hide)":"Team Name"},inplace=True)
master.loc[master.FinishTime.notnull(), "IsComplete"]=True
master.loc[master.IsComplete == True, 'Total Score']= master[["CP01","CP02","CP03","CP04","CP05","CP06","CP07", "CP08","CP09","CP10","CP11","CP12","CP13","CP14","CP15"]].sum(1)

master.FinishTime = pd.to_datetime(master.FinishTime)
master['FinishTime'] = master['FinishTime']+ timedelta(hours=8)
master.loc[master.IsComplete == True,'Total Time']=master["FinishTime"]-startTime
master['Total Time'] = master['Total Time'].astype(str).str.replace('0 days ', '')
master['Seconds'] = ''
master['Seconds'] = master['Total Time'] / pd.Timedelta(seconds=1)
master.loc[master.Seconds>7200, "IsComplete"]=False
master.loc[(master['CP05'] + master['CP06'] == 0), "IsComplete"]=False
master.loc[pd.isnull(master['CP05']) & pd.isnull(master['CP06']), "IsComplete"]=False
master.sort_values(by=['IsComplete', 'Total Score', 'Total Time', 'Team Name'], ascending=[False, False, True, True], inplace=True)

master = master.reset_index(drop=True)
master.index += 1
master.columns.name = 'Position'
master['Position'] = master.index
master.drop(labels=['Seconds'], axis=1, inplace=True)
master = master.fillna('abs')
order = ["Position","Team Name","CP01","CP02","CP03","CP04","CP05","CP06","CP07", "CP08","CP09","CP10","CP11","CP12","CP13","CP14","CP15","FinishTime","IsComplete","Total Time","Total Score"]
master= master[order]

public_list = master.copy()
public_list.drop(labels=['FinishTime',"CP01","CP02","CP03","CP04","CP05","CP06","CP07", "CP08","CP09","CP10","CP11","CP12","CP13","CP14","CP15"], axis=1, inplace=True)
public_list = public_list[public_list['Team Name'].astype(str).str.startswith('OPN')]
order_n = ["Position","Team Name","Total Time","Total Score","IsComplete"]
public_list= public_list[order_n]

master.sort_values(by=['Team Name'], ascending=[True], inplace=True)
master.to_csv('master_open.csv',sep=',', header=True, index=False)

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route("/")
def home():
    return render_template("open_template.html", column_names=public_list.columns.values, row_data=list(public_list.values.tolist()), zip=zip, date=gen_time)

app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Feb/2023 13:28:40] "GET / HTTP/1.1" 200 -
